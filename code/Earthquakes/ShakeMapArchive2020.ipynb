# %% [markdown]
# ###  Archive of ShakeMaps - http://strongmotioncenter.org/shake/archive/

# %%
import pandas as pd

# %%
from datetime import datetime, time, timezone, tzinfo
from dateutil import parser

# %%
table = pd.read_html('http://strongmotioncenter.org/shake/archive/',)

# %%
table
# Out:
# [                                                   0
#  0  Home  Map Archive  Related Links  Scientific B...,
#      0                                                  1
#  0 NaN  Home  Map Archive  Related Links  Scientific B...
#  1 NaN                     Archive of ShakeMaps from 2020
#  2 NaN                                                NaN,
#                     0                                                  1
#  0  Home  Map Archive  Related Links  Scientific Background  Disclaim...,
#        0   1            2   3
#  0  Home NaN  Map Archive NaN,
#      0              1   2                      3   4           5   6        7  \
#  0 NaN  Related Links NaN  Scientific Background NaN  Disclaimer NaN  Comment
#
#      8
#  0 NaN  ,
#                                  0
#  0  Archive of ShakeMaps from 2020,
#              0                                        1             2  \
#  0    Event ID                           Name/Epicenter          Date
# ...

# %%
type(table)
# Out:
# list

# %%
table[-1]
# Out:
#             0                                        1             2  \
# 0    Event ID                           Name/Epicenter          Date
# 1    73472891       10 km (6.25 mi) ESE of Willits, CA  Oct 19, 2020
# 2    73472896      11 km (6.875 mi) ESE of Willits, CA  Oct 19, 2020
# 3    39667688       23 km (14.375 mi) NW of Ludlow, CA  Oct 18, 2020
# 4    39666952      12 km (7.5 mi) N of Delta, B.C., MX  Oct 18, 2020
# ..        ...                                      ...           ...
# 166  39277736   4 km (2.5 mi) NNE of Granada Hills, CA  Jan 21, 2020
# 167  39033039    2 km (1.25 mi) WNW of Delta, B.C., MX  Jan 11, 2020
# 168  39028647   13 km (8.125 mi) ENE of Ridgecrest, CA   Jan 8, 2020
# 169  39020663  25 km (15.625 mi) S of Port Hueneme, CA   Jan 2, 2020
# 170  73322626   10 km (6.25 mi) ENE of Morgan Hill, CA   Jan 1, 2020
#
#                    3      4        5    6
# 0               Time    Lat      Lon  Mag
# 1    06:59:46 PM PDT  39.36  -123.25  3.4
# ...

# %%
pretty = table[-1]

# %%
type(pretty)
# Out:
# pandas.core.frame.DataFrame

# %%
pretty = pretty.iloc[1:].rename(columns = pretty.iloc[0,:])

# %%
pretty.head()
# Out:
#    Event ID                         Name/Epicenter          Date  \
# 1  73472891     10 km (6.25 mi) ESE of Willits, CA  Oct 19, 2020
# 2  73472896    11 km (6.875 mi) ESE of Willits, CA  Oct 19, 2020
# 3  39667688     23 km (14.375 mi) NW of Ludlow, CA  Oct 18, 2020
# 4  39666952    12 km (7.5 mi) N of Delta, B.C., MX  Oct 18, 2020
# 5  73470856  2 km (1.25 mi) ENE of Lopez Point, CA  Oct 14, 2020
#
#               Time    Lat      Lon  Mag
# 1  06:59:46 PM PDT  39.36  -123.25  3.4
# 2  06:58:50 PM PDT  39.37  -123.24  3.8
# 3  08:34:43 PM PDT  34.86  -116.34  3.5
# 4  03:31:34 AM PDT  32.46  -115.18  3.5
# 5  02:42:41 PM PDT  36.03  -121.54  3.5

# %%
pretty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 1 to 170
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event ID        170 non-null    object
#  1   Name/Epicenter  170 non-null    object
#  2   Date            170 non-null    object
#  3   Time            170 non-null    object
#  4   Lat             170 non-null    object
#  5   Lon             170 non-null    object
#  6   Mag             170 non-null    object
# dtypes: object(7)
# memory usage: 9.4+ KB

# %%
pretty.describe()
# Out:
#         Event ID                    Name/Epicenter          Date  \
# count        170                               170           170
# unique       170                               117            99
# top     39340599  30 km (18.75 mi) SE of Bodie, CA  Sep 30, 2020
# freq           1                                 8            19
#
#                    Time    Lat      Lon  Mag
# count               170    170      170  170
# unique              170     94       98   22
# top     12:29:29 PM PDT  38.05  -115.59  3.5
# freq                  1     11       10   38

# %%
table2 = pd.read_html('https://www.cisn.org/shakemap/nc/shake/archive/',)

# %%
pretty2 = table2[-1]
pretty2
# Out:
#            0                                        1             2  \
# 0   Event ID                           Name/Epicenter          Date
# 1   73472891      10.3 km (6.4 mi) ESE of Willits, CA  Oct 19, 2020
# 2   73472896      10.7 km (6.7 mi) ESE of Willits, CA  Oct 19, 2020
# 3   73470856   2.1 km (1.3 mi) ENE of Lopez Point, CA  Oct 14, 2020
# 4   73468941      29.5 km (18.3 mi) NNE of Redway, CA   Oct 9, 2020
# ..       ...                                      ...           ...
# 58  73340375   11.6 km (7.2 mi) SSE of Tres Pinos, CA  Feb 12, 2020
# 59  73336226      8.7 km (5.4 mi) WSW of Petrolia, CA   Feb 6, 2020
# 60  73334451   12.9 km (8.0 mi) WNW of Toms Place, CA   Feb 1, 2020
# 61  73333256  1.5 km (1.0 mi) W of Redwood Valley, CA  Jan 29, 2020
# 62  73322626   9.5 km (5.9 mi) ENE of Morgan Hill, CA   Jan 1, 2020
#
#                   3      4        5    6
# 0              Time    Lat      Lon  Mag
# 1   06:59:46 PM PDT  39.36  -123.25  3.4
# ...

# %%
pretty2 = pretty2.iloc[1:].rename(columns = pretty2.iloc[0,:])
pretty2
# Out:
#     Event ID                           Name/Epicenter          Date  \
# 1   73472891      10.3 km (6.4 mi) ESE of Willits, CA  Oct 19, 2020
# 2   73472896      10.7 km (6.7 mi) ESE of Willits, CA  Oct 19, 2020
# 3   73470856   2.1 km (1.3 mi) ENE of Lopez Point, CA  Oct 14, 2020
# 4   73468941      29.5 km (18.3 mi) NNE of Redway, CA   Oct 9, 2020
# 5   73466751    14.8 km (9.2 mi) SW of Toms Place, CA   Oct 4, 2020
# ..       ...                                      ...           ...
# 58  73340375   11.6 km (7.2 mi) SSE of Tres Pinos, CA  Feb 12, 2020
# 59  73336226      8.7 km (5.4 mi) WSW of Petrolia, CA   Feb 6, 2020
# 60  73334451   12.9 km (8.0 mi) WNW of Toms Place, CA   Feb 1, 2020
# 61  73333256  1.5 km (1.0 mi) W of Redwood Valley, CA  Jan 29, 2020
# 62  73322626   9.5 km (5.9 mi) ENE of Morgan Hill, CA   Jan 1, 2020
#
#                Time    Lat      Lon  Mag
# 1   06:59:46 PM PDT  39.36  -123.25  3.4
# 2   06:58:50 PM PDT  39.37  -123.24  3.8
# ...

# %%
table3 = pd.read_html('https://www.cisn.org/shakemap/sc/shake/archive/',)

# %%
pretty3 = table3[-1]
pretty3
# Out:
#             0                                         1             2  \
# 0    Event ID                            Name/Epicenter          Date
# 1    39667688        22.7 km (14.1 mi) NW of Ludlow, CA  Oct 19, 2020
# 2    39666952     12.3 km (7.6 mi) N of Delta, B.C., MX  Oct 18, 2020
# 3    39654952   10.5 km (6.5 mi) N of Big Bear City, CA   Oct 7, 2020
# 4    39651784    3.7 km (2.3 mi) ESE of Westmorland, CA   Oct 3, 2020
# ..        ...                                       ...           ...
# 131  39033039    2.3 km (1.4 mi) WNW of Delta, B.C., MX  Jan 12, 2020
# 132  39028647    13.2 km (8.2 mi) ENE of Ridgecrest, CA   Jan 8, 2020
# 133  39024383           3.0 km (1.9 mi) ENE of Brea, CA   Jan 5, 2020
# 134  39020663   25.4 km (15.8 mi) S of Port Hueneme, CA   Jan 2, 2020
# 135  39019703  11.0 km (6.8 mi) ENE of North Tustin, CA   Jan 1, 2020
#
#                    3      4        5    6
# 0               Time    Lat      Lon  Mag
# ...

# %%
pretty3 = pretty3.iloc[1:].rename(columns = pretty3.iloc[0,:])
pretty3
# Out:
#      Event ID                            Name/Epicenter          Date  \
# 1    39667688        22.7 km (14.1 mi) NW of Ludlow, CA  Oct 19, 2020
# 2    39666952     12.3 km (7.6 mi) N of Delta, B.C., MX  Oct 18, 2020
# 3    39654952   10.5 km (6.5 mi) N of Big Bear City, CA   Oct 7, 2020
# 4    39651784    3.7 km (2.3 mi) ESE of Westmorland, CA   Oct 3, 2020
# 5    39649056    5.3 km (3.3 mi) ENE of Westmorland, CA   Oct 2, 2020
# ..        ...                                       ...           ...
# 131  39033039    2.3 km (1.4 mi) WNW of Delta, B.C., MX  Jan 12, 2020
# 132  39028647    13.2 km (8.2 mi) ENE of Ridgecrest, CA   Jan 8, 2020
# 133  39024383           3.0 km (1.9 mi) ENE of Brea, CA   Jan 5, 2020
# 134  39020663   25.4 km (15.8 mi) S of Port Hueneme, CA   Jan 2, 2020
# 135  39019703  11.0 km (6.8 mi) ENE of North Tustin, CA   Jan 1, 2020
#
#                 Time    Lat      Lon  Mag
# 1    03:34:43 AM UTC  34.86  -116.34  3.5
# ...

# %%
all_pretty = pretty.append(pretty2.append(pretty3)).reset_index(drop=True)

# %%
all_pretty.sort_values(by='Event ID')
# Out:
#      Event ID                            Name/Epicenter          Date  \
# 72   00756843                30.7 (19.2mi) SE of Bodie,   Jul 4, 2020
# 82   37447621     18 km (11.25 mi) SSE of Lone Pine, CA  Jun 22, 2020
# 309  37447621    17.6 km (10.9 mi) SSE of Lone Pine, CA  Jun 23, 2020
# 282  37452101  13.9 km (8.6 mi) SSE of Bombay Beach, CA  Aug 10, 2020
# 243  37456405    4.6 km (2.9 mi) ENE of Westmorland, CA   Oct 1, 2020
# ..        ...                                       ...           ...
# 4    73470856     2 km (1.25 mi) ENE of Lopez Point, CA  Oct 14, 2020
# 170  73472891       10.3 km (6.4 mi) ESE of Willits, CA  Oct 19, 2020
# 0    73472891        10 km (6.25 mi) ESE of Willits, CA  Oct 19, 2020
# 1    73472896       11 km (6.875 mi) ESE of Willits, CA  Oct 19, 2020
# 171  73472896       10.7 km (6.7 mi) ESE of Willits, CA  Oct 19, 2020
#
#                 Time    Lat      Lon  Mag
# 72   01:09:38 PM PDT  38.05  -118.73  3.5
# ...

# %%
all_pretty.duplicated(subset='Event ID')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 362     True
# 363     True
# 364    False
# 365     True
# 366    False
# Length: 367, dtype: bool

# %%
all_pretty.loc[all_pretty.duplicated(subset='Event ID')]
# Out:
#      Event ID                            Name/Epicenter          Date  \
# 170  73472891       10.3 km (6.4 mi) ESE of Willits, CA  Oct 19, 2020
# 171  73472896       10.7 km (6.7 mi) ESE of Willits, CA  Oct 19, 2020
# 172  73470856    2.1 km (1.3 mi) ENE of Lopez Point, CA  Oct 14, 2020
# 173  73468941       29.5 km (18.3 mi) NNE of Redway, CA   Oct 9, 2020
# 175  73466321       10.6 km (6.6 mi) ESE of Willits, CA   Oct 3, 2020
# ..        ...                                       ...           ...
# 360  39281440      22.6 km (14.1 mi) NNE of Barstow, CA  Jan 25, 2020
# 361  39277736  3.5 km (2.2 mi) NNE of Granada Hills, CA  Jan 22, 2020
# 362  39033039    2.3 km (1.4 mi) WNW of Delta, B.C., MX  Jan 12, 2020
# 363  39028647    13.2 km (8.2 mi) ENE of Ridgecrest, CA   Jan 8, 2020
# 365  39020663   25.4 km (15.8 mi) S of Port Hueneme, CA   Jan 2, 2020
#
#                 Time    Lat      Lon  Mag
# 170  06:59:46 PM PDT  39.36  -123.25  3.4
# ...

# %%
single = all_pretty.drop_duplicates(subset='Event ID').copy()

# %%
single.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 366
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event ID        200 non-null    object
#  1   Name/Epicenter  200 non-null    object
#  2   Date            200 non-null    object
#  3   Time            200 non-null    object
#  4   Lat             200 non-null    object
#  5   Lon             200 non-null    object
#  6   Mag             200 non-null    object
# dtypes: object(7)
# memory usage: 12.5+ KB

# %%
#NEXT STEP -- convert dtypes

# %%
single['Date'] = pd.to_datetime(single['Date'])

# %%
'%I:%M:%S %p %Z'
# Out:
# '%I:%M:%S %p %Z'

# %%
datetime.strptime(single.loc[single['Time'].str.contains('PST')], '%I:%M:%S %p %Z')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-3360a8293bc6> in <module>
# ----> 1 datetime.strptime(single.loc[single['Time'].str.contains('PST')], '%I:%M:%S %p %Z')
#
# TypeError: strptime() argument 1 must be str, not DataFrame

# %%
for i in single['Time']:
    pd.to_datetime(i, tzinf)

# %%
single.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 366
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event ID        200 non-null    object
#  1   Name/Epicenter  200 non-null    object
#  2   Date            200 non-null    object
#  3   Time            200 non-null    object
#  4   Lat             200 non-null    object
#  5   Lon             200 non-null    object
#  6   Mag             200 non-null    object
# dtypes: object(7)
# memory usage: 12.5+ KB

# %%
single['Lat'] = pd.to_numeric(single['Lat'])

# %%
single['Lon'] = pd.to_numeric(single['Lon'])

# %%
single['Mag'] = pd.to_numeric(single['Mag'])

# %%
single.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 366
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Event ID        200 non-null    object
#  1   Name/Epicenter  200 non-null    object
#  2   Date            200 non-null    datetime64[ns]
#  3   Time            200 non-null    object
#  4   Lat             200 non-null    float64
#  5   Lon             200 non-null    float64
#  6   Mag             200 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 12.5+ KB

# %%
single
# Out:
#      Event ID                                     Name/Epicenter       Date  \
# 0    73472891                 10 km (6.25 mi) ESE of Willits, CA 2020-10-19
# 1    73472896                11 km (6.875 mi) ESE of Willits, CA 2020-10-19
# 2    39667688                 23 km (14.375 mi) NW of Ludlow, CA 2020-10-18
# 3    39666952                12 km (7.5 mi) N of Delta, B.C., MX 2020-10-18
# 4    73470856              2 km (1.25 mi) ENE of Lopez Point, CA 2020-10-14
# ..        ...                                                ...        ...
# 352  38395986          21.2 km (13.2 mi) N of Searles Valley, CA 2020-03-17
# 355  38385946  71.0 km (44.1 mi) SE of Estacion Coahuila, B.C... 2020-03-07
# 359  39286080       33.8 km (21.0 mi) ENE of Maneadero, B.C., MX 2020-01-29
# 364  39024383                    3.0 km (1.9 mi) ENE of Brea, CA 2020-01-05
# 366  39019703           11.0 km (6.8 mi) ENE of North Tustin, CA 2020-01-01
#
#                 Time    Lat     Lon  Mag
# ...

# %%
single.drop('Time', axis =1 , inplace=True)

# %%
single.head()
# Out:
#    Event ID                         Name/Epicenter       Date    Lat     Lon  \
# 0  73472891     10 km (6.25 mi) ESE of Willits, CA 2020-10-19  39.36 -123.25
# 1  73472896    11 km (6.875 mi) ESE of Willits, CA 2020-10-19  39.37 -123.24
# 2  39667688     23 km (14.375 mi) NW of Ludlow, CA 2020-10-18  34.86 -116.34
# 3  39666952    12 km (7.5 mi) N of Delta, B.C., MX 2020-10-18  32.46 -115.18
# 4  73470856  2 km (1.25 mi) ENE of Lopez Point, CA 2020-10-14  36.03 -121.54
#
#    Mag
# 0  3.4
# 1  3.8
# 2  3.5
# 3  3.5
# 4  3.5

# %%
single.to_csv('../../data/earthquakes_CA.csv', index=False)
