# %%
import pandas as pd

# %%
active_fires_url = 'https://www.fire.ca.gov/umbraco/api/IncidentApi/List?inactive=flase'
active_fires = pd.read_json(active_fires_url)
inactive_fires_url = 'https://www.fire.ca.gov/umbraco/api/IncidentApi/List?inactive=true'
inactive_fires = pd.read_json(inactive_fires_url)
fires_2020 = inactive_fires[inactive_fires['ExtinguishedDateOnly'].str.contains('2020')]
fires = pd.concat([active_fires, fires_2020])

# %%
fires.head()
# Out:
#                                  Name  Final                   Updated  \
# 0                          Apple Fire  False  2020-10-15T10:26:55.453Z
# 1  August Complex (includes Doe Fire)  False   2020-10-17T09:21:58.54Z
# 2                  Red Salmon Complex  False   2020-08-18T09:49:34.58Z
# 3                       Blue Jay Fire  False  2020-09-22T12:47:56.527Z
# 4                  North Complex Fire  False  2020-10-05T07:12:04.723Z
#
#                    Started                                          AdminUnit  \
# 0     2020-07-31T18:08:39Z  Unified Command: USFS - San Bernardino, and Yu...
# 1     2020-08-16T20:37:26Z  Mendocino National Forest, CAL FIRE Mendocino ...
# 2  2020-08-18T09:49:34.58Z                    Shasta-Trinity National Forest
# 3     2020-08-18T10:16:11Z                          Yosemite National Forest
# 4     2020-08-18T21:21:53Z                            Plumas National Forest
#
#    AdminUnitUrl                                             County  \
# ...

# %%
fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 0 to 2519
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  202 non-null    object
#  1   Final                 202 non-null    bool
#  2   Updated               202 non-null    object
#  3   Started               202 non-null    object
#  4   AdminUnit             196 non-null    object
#  5   AdminUnitUrl          0 non-null      float64
#  6   County                202 non-null    object
#  7   Location              202 non-null    object
#  8   AcresBurned           202 non-null    int64
#  9   PercentContained      202 non-null    int64
#  10  ControlStatement      9 non-null      object
#  11  AgencyNames           202 non-null    object
#  12  Longitude             202 non-null    float64
#  13  Latitude              202 non-null    float64
#  14  Type                  202 non-null    object
# ...

# %%
#finding null values
fires.isnull().sum()
# Out:
# Name                      0
# Final                     0
# Updated                   0
# Started                   0
# AdminUnit                 6
# AdminUnitUrl            202
# County                    0
# Location                  0
# AcresBurned               0
# PercentContained          0
# ControlStatement        193
# AgencyNames               0
# Longitude                 0
# Latitude                  0
# Type                      0
# UniqueId                  0
# Url                       0
# ExtinguishedDate          0
# ExtinguishedDateOnly      0
# StartedDateOnly           0
# IsActive                  0
# CalFireIncident           0
# NotificationDesired       0
# dtype: int64

# %%
#dropping columns with so many null values
fires.drop(columns=['AdminUnitUrl', 'ControlStatement'], inplace=True)

# %%
fires.isnull().sum()
# Out:
# Name                    0
# Final                   0
# Updated                 0
# Started                 0
# AdminUnit               6
# County                  0
# Location                0
# AcresBurned             0
# PercentContained        0
# AgencyNames             0
# Longitude               0
# Latitude                0
# Type                    0
# UniqueId                0
# Url                     0
# ExtinguishedDate        0
# ExtinguishedDateOnly    0
# StartedDateOnly         0
# IsActive                0
# CalFireIncident         0
# NotificationDesired     0
# dtype: int64

# %%
#printing all the column names
pd.set_option('display.max_columns', None)
fires.head(1)
# Out:
#          Name  Final                   Updated               Started  \
# 0  Apple Fire  False  2020-10-15T10:26:55.453Z  2020-07-31T18:08:39Z
#
#                                            AdminUnit     County  \
# 0  Unified Command: USFS - San Bernardino, and Yu...  Riverside
#
#                                             Location  AcresBurned  \
# 0  off of Oak Glen Road and Apple Tree Lane, Nort...            0
#
#    PercentContained                                        AgencyNames  \
# 0                 0  United States Forest Service, CAL FIRE / River...
#
#    Longitude  Latitude      Type                              UniqueId  \
# 0  -116.9617  33.99139  Wildfire  8b9ae457-96ea-4041-912c-6b33e8498d98
#
#                                                  Url ExtinguishedDate  \
# 0  https://www.fire.ca.gov/incidents/2020/7/31/ap...
#
#   ExtinguishedDateOnly       StartedDateOnly  IsActive  CalFireIncident  \
# ...

# %%
fires.columns
# Out:
# Index(['Name', 'Final', 'Updated', 'Started', 'AdminUnit', 'County',
#        'Location', 'AcresBurned', 'PercentContained', 'AgencyNames',
#        'Longitude', 'Latitude', 'Type', 'UniqueId', 'Url', 'ExtinguishedDate',
#        'ExtinguishedDateOnly', 'StartedDateOnly', 'IsActive',
#        'CalFireIncident', 'NotificationDesired'],
#       dtype='object')

# %%
#make a new dataframe from the necessary columns
fires_df=fires[['Name', 'Final', 'Started',  'County',
        'AcresBurned', 'PercentContained',
       'Longitude', 'Latitude','Type', 'IsActive',
       'CalFireIncident', 'Location']]

# %%
fires_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 0 to 2519
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              202 non-null    object
#  1   Final             202 non-null    bool
#  2   Started           202 non-null    object
#  3   County            202 non-null    object
#  4   AcresBurned       202 non-null    int64
#  5   PercentContained  202 non-null    int64
#  6   Longitude         202 non-null    float64
#  7   Latitude          202 non-null    float64
#  8   Type              202 non-null    object
#  9   IsActive          202 non-null    bool
#  10  CalFireIncident   202 non-null    bool
#  11  Location          202 non-null    object
# dtypes: bool(3), float64(2), int64(2), object(5)
# memory usage: 16.4+ KB

# %%
fires_df.isnull().sum()
# Out:
# Name                0
# Final               0
# Started             0
# County              0
# AcresBurned         0
# PercentContained    0
# Longitude           0
# Latitude            0
# Type                0
# IsActive            0
# CalFireIncident     0
# Location            0
# dtype: int64
